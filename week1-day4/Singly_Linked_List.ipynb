# %% [markdown]
# <a href="https://colab.research.google.com/github/aahmedfaraz/icodeguru-course-understanding-data-structures/blob/main/week1-day4/Singly_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Singly Linked List Overview

# %%
# Singly Linked List
# list: a collection of items (nodes in this case)
# linked: connected to form a collection (using pointer in this case)
# singly: single connection for each node (next pointer for each node)

# %% [markdown]
# Node: An item that contains data and pointer
#
# Pointer: A reference to next node

# %% [markdown]
# ![Screenshot 2026-01-01 161457.png](data:image/png;base64,...)

# %% [markdown]
# Node:
#
# 17 - Data
#
# 4400 - Pointer to next Node
#
# 4000 - Current node address (last node points to this)

# %% [markdown]
# ![Screenshot 2026-01-01 161754.png](data:image/png;base64,...)

# %% [markdown]
# Singly Linked List
#
# Head: Pointer to the first node of the list
#
# Null Pointer: Pointer that the last node uses (indicates end of list)

# %% [markdown]
# ![Screenshot 2026-01-01 162236.png](data:image/png;base64,...)

# %% [markdown]
# # Node (code)

# %%
class Node:
    def __init__(self, data=None):
        self.data = data # data stored in node
        self.next = None # pointer to next node

node1 = Node("A")
print(node1)
print(node1.data)
print(node1.next)
# Out:
# <__main__.Node object at 0x7ebf34d111c0>
# A
# None

# %%
# identity and address
print(node1) # identity of the object

# id() unique id of object
print(id(node1)) # memory address in CPython (version of Python)
# Out:
# <__main__.Node object at 0x7ebf34d111c0>
# 139359689970112

# %%
node2 = Node("B")
print(node2.data)
print(node2.next)

print(node2)
print(id(node2))
# Out:
# B
# None
# <__main__.Node object at 0x7ebf34d10e30>
# 139359689969200

# %%
# Linking Nodes
# Link is established using pointer

node1.next = node2
# now node1 points to node2

print(node1.data, node1.next)
print(id(node1.next), "id of node1.next")
print(id(node2), "id of node2")
# Out:
# A <__main__.Node object at 0x7ebf34d10e30>
# 139359689969200 id of node1.next
# 139359689969200 id of node2

# %% [markdown]
# ![Screenshot 2026-01-01 164604.png](data:image/png;base64,...)

# %%
head = node1
print(head.data)
# Out:
# A

# %% [markdown]
# # Creating Linked List (code)

# %%
# function to link nodes and create list
def insert_at_start(head, data):
    new_node = Node(data) # create node
    new_node.next = head # connect to head | node -> head (prev_node)
    return new_node # return head (new_node is the head)

# %%
head = None # None
head = insert_at_start(head, "a") # a -> None
head = insert_at_start(head, "b") # b -> a -> None
head = insert_at_start(head, "c") # c -> b -> a - > None
head = insert_at_start(head, "d") # d -> c -> b -> a -> None
head = insert_at_start(head, "e") # e -> d -> c -> b -> a -> None

# %% [markdown]
# # List Main Functions

# %% [markdown]
# ## Traversion

# %%
# Visiting every node once
# we move through next pointer

def traverse_list(head):
  curr = head # current node
  print(curr.data)

  while curr.next != None: # check if there is a node ahead
    curr = curr.next # move to that node
    print(curr.data)

traverse_list(head)
# Out:
# e
# d
# c
# b
# a

# %% [markdown]
# Time Complexity O(n)
#
# Space Complexity O(1)

# %% [markdown]
# ## Insertion

# %% [markdown]
# ### Insertion at Start

# %%
def insert_at_start(head, data):
    new_node = Node(data) # create node
    new_node.next = head # connect to head | node -> head (prev_node)
    return new_node # return head (new_node is the head)

head = insert_at_start(head, "f")

# %%
# lets check it
traverse_list(head)
# Out:
# f
# e
# d
# c
# b
# a

# %% [markdown]
# Time Complexity O(1)
#
# Space Complexity O(1)

# %% [markdown]
# ### Insertion at End

# %%
# basic check
# move to end
# insert node
# connect to list

def insert_at_end(head, data):
    new_node = Node(data)

    # check if list is empty, then its first node
    if head is None:
        return new_node

    # move to end (traverse)
    curr = head
    while curr.next:
        curr = curr.next

    curr.next = new_node # connect node | last_node -> new_node
    return head

head = insert_at_end(head, "g")

# %%
# lets check it
traverse_list(head)
# Out:
# f
# e
# d
# c
# b
# a
# g

# %% [markdown]
# Time Complexity O(n)
#
# Space Complexity O(1)

# %% [markdown]
# ### Insert after a given node

# %%
# basic check
# we access nodes through next pointer
# so we can insert new node next to a given node

def insert_at_specific(node, data):
    if node is None:
        print("Error: The given node is None")
        return

    new_node = Node(data) # create node
    new_node.next = node.next # connect to next | new_node -> node.next
    node.next = new_node # connect to previous | node -> new_node

insert_at_specific(head, "h")

# %%
# lets check it
traverse_list(head)
# Out:
# f
# h
# e
# d
# c
# b
# a
# g

# %% [markdown]
# Time Complexity O(1)
#
# Space Complexity O(1)

# %% [markdown]
# ## Deletion

# %% [markdown]
# ### Deletion at Start

# %%
# basic check
# point head to 2nd node
# delete 1st node
# return new head

def delete_from_start(head):
  # basic check
  if head is None: # list is empty
    print("Error: Singly linked list is empty")
    return None

  new_head = head.next
  return new_head

head = delete_from_start(head)

# %%
# lets check it
traverse_list(head)
# Out:
# h
# e
# d
# c
# b
# a
# g

# %% [markdown]
# Time Complexity O(1)
#
# Space Complexity O(1)

# %% [markdown]
# ### Deletion from end

# %%
# basic check
# last node can be accessed through 2nd last node's next pointer
# so go to 2nd last node, update pointer

def delete_at_end(head):
    # basic check
    if head is None or head.next is None:
        print("Error: Singly linked list is empty or has only one node")
        return None

    # move to 2nd last node (note next.next)
    curr = head
    while curr.next.next: # differnece between traversion to last node and this
        curr = curr.next

    del_node = curr.next # last node stored
    curr.next = None # 2nd last points to None, so ends the list
    # del del_node

    return head

head = delete_at_end(head)

# %%
# lets check it
traverse_list(head)
# Out:
# h
# e
# d
# c
# b

# %% [markdown]
# Time Complexity
#
# Space Complexity

# %% [markdown]
# ### Deletion after a given node

# %%
# basic check
# update next pointer of given node

def delete_after_node(node):
    # basic check: no node, or only node
    if node is None or node.next is None:
        print("Error: The given node is None or the next node is None")
        return

    next_node = node.next
    node.next = next_node.next
    # node.next = node.next.next

delete_after_node(head.next)

# %%
traverse_list(head)
# Out:
# h
# e
# c
# b

# %% [markdown]
# Time Complexity
#
# Space Complexity

# %% [markdown]
# # Faida kya hua?
#
# Lets compare it to list (array)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
